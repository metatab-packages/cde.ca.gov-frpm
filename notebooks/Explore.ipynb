# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# <p><code>cde.ca.gov-frpm-1</code> Last Update: 2019-04-03T20:13:35</p>
# <p>__</p>
# <h2>Contacts</h2>
# <ul>
# <li><strong>Wrangler</strong> <a href="mailto:eric@civicknowledge.com">Eric Busboom</a>, <a href="http://civicknowledge.com">Civic Knowledge</a></li>
# </ul>
# <h2>Resources</h2>
# <ul>
# <li><strong> <a href="data/frpm04.csv">frpm04</a></strong>. Free and Reduced Price Meals, 2004</li>
# <li><strong> <a href="data/frpm05.csv">frpm05</a></strong>. Free and Reduced Price Meals, 2005</li>
# <li><strong> <a href="data/frpm06.csv">frpm06</a></strong>. Free and Reduced Price Meals, 2006</li>
# <li><strong> <a href="data/frpm07.csv">frpm07</a></strong>. Free and Reduced Price Meals, 2007</li>
# <li><strong> <a href="data/frpm08.csv">frpm08</a></strong>. Free and Reduced Price Meals, 2008</li>
# <li><strong> <a href="data/frpm09.csv">frpm09</a></strong>. Free and Reduced Price Meals, 2009</li>
# <li><strong> <a href="data/frpm10.csv">frpm10</a></strong>. Free and Reduced Price Meals, 2010</li>
# <li><strong> <a href="data/frpm11.csv">frpm11</a></strong>. Free and Reduced Price Meals, 2011</li>
# <li><strong> <a href="data/frpm12.csv">frpm12</a></strong>. Free and Reduced Price Meals, 2012</li>
# <li><strong> <a href="data/frpm13.csv">frpm13</a></strong>. Free and Reduced Price Meals, 2013</li>
# <li><strong> <a href="data/frpm14.csv">frpm14</a></strong>. Free and Reduced Price Meals, 2014</li>
# <li><strong> <a href="data/frpm15.csv">frpm15</a></strong>. Free and Reduced Price Meals, 2015</li>
# <li><strong> <a href="data/frpm16.csv">frpm16</a></strong>. Free and Reduced Price Meals, 2016</li>
# <li><strong> <a href="data/frpm17.csv">frpm17</a></strong>. Free and Reduced Price Meals, 2017</li>
# <li><strong> <a href="data/frpm18.csv">frpm18</a></strong>. Free and Reduced Price Meals, 2018</li>
# <li><strong> <a href="data/combined.csv">combined</a></strong>. Combined data, 2004 to 2018</li>
# </ul>

# %%
df = pkg.resource('combined').dataframe()

# %%
df.head()
# Out:
#    year academic_year  county_code county_name  district_code district_name  \
# 0  2004           NaN          1.0         NaN        10017.0           NaN
# 1  2004           NaN          1.0         NaN        10017.0           NaN
# 2  2004           NaN          1.0         NaN        61119.0           NaN
# 3  2004           NaN          1.0         NaN        61119.0           NaN
# 4  2004           NaN          1.0         NaN        61119.0           NaN
#
#   district_type  school_code                                school_name  \
# 0           NaN     130419.0                           County Community
# 1           NaN     130427.0                    Alternative/Opportunity
# 2           NaN     130229.0                               Alameda High
# 3           NaN     130609.0  Arthur Anderson Community Learning Center
# 4           NaN     130625.0              Bay Area School of Enterprise
#
#   school_type                   ...                    \
# 0         NaN                   ...
# 1         NaN                   ...
# 2         NaN                   ...
# 3         NaN                   ...
# 4         NaN                   ...
#
#   percent_eligible_frpm_k_12 percent_frpm reduced_price_meals total_frpm  \
# 0                        NaN     0.760736                 9.0      124.0
# 1                        NaN     0.882353                 7.0      105.0
# 2                        NaN     0.178862                88.0      330.0
# 3                        NaN     0.135678                 4.0       27.0
# 4                        NaN     0.458333                15.0       44.0
#
#   unadjusted_free_meal_count unadjusted_free_meal_count_k_12  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#   unadjusted_frpm_count unadjusted_frpm_count_k_12 data_source_for_frpm  \
# 0                   NaN                        NaN                  NaN
# 1                   NaN                        NaN                  NaN
# 2                   NaN                        NaN                  NaN
# 3                   NaN                        NaN                  NaN
# 4                   NaN                        NaN                  NaN
#
#   data_source_for_provision_2_or_3_school
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
# [5 rows x 47 columns]

# %%
df[df.percent_frpm < 1].percent_frpm.hist()

# %%
df[df.percent_frpm > 1].head().T
# Out:
#                                                                       38278  \
# year                                                                   2008
# academic_year                                                           NaN
# county_code                                                               1
# county_name                                                         Alameda
# district_code                                                         10017
# district_name                                                           NaN
# district_type                                                           NaN
# school_code                                                     6.10675e+06
# school_name                                Alameda County Special Education
# school_type                                                             NaN
# lea_name                                 Alameda County Office of Education
# charter_funding_type                                                    NaN
# charter_school_number                                                   NaN
# charter_school_y_n                                                      NaN
# direct_funded_charter_school_number                                     NaN
# low_grade                                                                KK
# high_grade                                                               12
# educational_option_type                                                 NaN
# irc                                                                     NaN
# fund_type                                                               NaN
# nslp_provision_2_or_3_school                                            NaN
# nslp_provision_status                                                   NaN
# provision_2_or_3_school_y_n                                             NaN
# calpads_enrollment                                                      NaN
# calpads_enrollment_k_12                                                 NaN
# enrollment                                                                0
# enrollment_k_12                                                         NaN
# calpads_fall_1_certification_status                                     NaN
# free_meal_count                                                           0
# free_meal_count_k_12                                                    NaN
# frpm_count                                                              NaN
# frpm_count_k_12                                                         NaN
# frpm_total_unduplicated_count                                           NaN
# frpm_total_unduplicated_count_k_12                                      NaN
# percent_eligible_free                                                   NaN
# percent_eligible_free_k_12                                              NaN
# percent_eligible_frpm                                                   NaN
# percent_eligible_frpm_k_12                                              NaN
# percent_frpm                                                              7
# reduced_price_meals                                                       0
# total_frpm                                                                0
# unadjusted_free_meal_count                                              NaN
# unadjusted_free_meal_count_k_12                                         NaN
# unadjusted_frpm_count                                                   NaN
# unadjusted_frpm_count_k_12                                              NaN
# data_source_for_frpm                                                    NaN
# data_source_for_provision_2_or_3_school                                 NaN
#
#                                                                              38447  \
# year                                                                          2008
# academic_year                                                                  NaN
# county_code                                                                      1
# county_name                                                                Alameda
# district_code                                                                61242
# district_name                                                                  NaN
# district_type                                                                  NaN
# school_code                                                                 114629
# school_name                              New Haven Community Day School at Cabello
# school_type                                                                    NaN
# lea_name                                                         New Haven Unified
# charter_funding_type                                                           NaN
# charter_school_number                                                          NaN
# charter_school_y_n                                                             NaN
# direct_funded_charter_school_number                                            NaN
# low_grade                                                                       07
# high_grade                                                                      12
# educational_option_type                                                        NaN
# irc                                                                            NaN
# fund_type                                                                      NaN
# nslp_provision_2_or_3_school                                                   NaN
# nslp_provision_status                                                          NaN
# provision_2_or_3_school_y_n                                                    NaN
# calpads_enrollment                                                             NaN
# calpads_enrollment_k_12                                                        NaN
# enrollment                                                                       0
# enrollment_k_12                                                                NaN
# calpads_fall_1_certification_status                                            NaN
# free_meal_count                                                                  0
# free_meal_count_k_12                                                           NaN
# frpm_count                                                                     NaN
# frpm_count_k_12                                                                NaN
# frpm_total_unduplicated_count                                                  NaN
# frpm_total_unduplicated_count_k_12                                             NaN
# percent_eligible_free                                                          NaN
# percent_eligible_free_k_12                                                     NaN
# percent_eligible_frpm                                                          NaN
# percent_eligible_frpm_k_12                                                     NaN
# percent_frpm                                                                     7
# reduced_price_meals                                                              0
# total_frpm                                                                       0
# unadjusted_free_meal_count                                                     NaN
# unadjusted_free_meal_count_k_12                                                NaN
# unadjusted_frpm_count                                                          NaN
# unadjusted_frpm_count_k_12                                                     NaN
# data_source_for_frpm                                                           NaN
# data_source_for_provision_2_or_3_school                                        NaN
#
#                                                                 38473  \
# year                                                             2008
# academic_year                                                     NaN
# county_code                                                         1
# county_name                                                   Alameda
# district_code                                                   61259
# district_name                                                     NaN
# district_type                                                     NaN
# school_code                                                    106559
# school_name                              Oakland Community Day Middle
# school_type                                                       NaN
# lea_name                                              Oakland Unified
# charter_funding_type                                              NaN
# charter_school_number                                             NaN
# charter_school_y_n                                                NaN
# direct_funded_charter_school_number                               NaN
# low_grade                                                          06
# high_grade                                                         08
# educational_option_type                                           NaN
# irc                                                               NaN
# fund_type                                                         NaN
# nslp_provision_2_or_3_school                                      NaN
# nslp_provision_status                                             NaN
# provision_2_or_3_school_y_n                                       NaN
# calpads_enrollment                                                NaN
# calpads_enrollment_k_12                                           NaN
# enrollment                                                          0
# enrollment_k_12                                                   NaN
# calpads_fall_1_certification_status                               NaN
# free_meal_count                                                     0
# free_meal_count_k_12                                              NaN
# frpm_count                                                        NaN
# frpm_count_k_12                                                   NaN
# frpm_total_unduplicated_count                                     NaN
# frpm_total_unduplicated_count_k_12                                NaN
# percent_eligible_free                                             NaN
# percent_eligible_free_k_12                                        NaN
# percent_eligible_frpm                                             NaN
# percent_eligible_frpm_k_12                                        NaN
# percent_frpm                                                        7
# reduced_price_meals                                                 0
# total_frpm                                                          0
# unadjusted_free_meal_count                                        NaN
# unadjusted_free_meal_count_k_12                                   NaN
# unadjusted_frpm_count                                             NaN
# unadjusted_frpm_count_k_12                                        NaN
# data_source_for_frpm                                              NaN
# data_source_for_provision_2_or_3_school                           NaN
#
#                                                                                  38506  \
# year                                                                              2008
# academic_year                                                                      NaN
# county_code                                                                          1
# county_name                                                                    Alameda
# district_code                                                                    61259
# district_name                                                                      NaN
# district_type                                                                      NaN
# school_code                                                                     115386
# school_name                              East Bay Conservation Corps Corpsmember Acade
# school_type                                                                        NaN
# lea_name                                                               Oakland Unified
# charter_funding_type                                                               NaN
# charter_school_number                                                              NaN
# charter_school_y_n                                                                 NaN
# direct_funded_charter_school_number                                               0948
# low_grade                                                                           09
# high_grade                                                                          12
# educational_option_type                                                            NaN
# irc                                                                                NaN
# fund_type                                                                          NaN
# nslp_provision_2_or_3_school                                                       NaN
# nslp_provision_status                                                              NaN
# provision_2_or_3_school_y_n                                                        NaN
# calpads_enrollment                                                                 NaN
# calpads_enrollment_k_12                                                            NaN
# enrollment                                                                           0
# enrollment_k_12                                                                    NaN
# calpads_fall_1_certification_status                                                NaN
# free_meal_count                                                                      0
# free_meal_count_k_12                                                               NaN
# frpm_count                                                                         NaN
# frpm_count_k_12                                                                    NaN
# frpm_total_unduplicated_count                                                      NaN
# frpm_total_unduplicated_count_k_12                                                 NaN
# percent_eligible_free                                                              NaN
# percent_eligible_free_k_12                                                         NaN
# percent_eligible_frpm                                                              NaN
# percent_eligible_frpm_k_12                                                         NaN
# percent_frpm                                                                         7
# reduced_price_meals                                                                  0
# total_frpm                                                                           0
# unadjusted_free_meal_count                                                         NaN
# unadjusted_free_meal_count_k_12                                                    NaN
# unadjusted_frpm_count                                                              NaN
# unadjusted_frpm_count_k_12                                                         NaN
# data_source_for_frpm                                                               NaN
# data_source_for_provision_2_or_3_school                                            NaN
#
#                                                                38602
# year                                                            2008
# academic_year                                                    NaN
# county_code                                                        1
# county_name                                                  Alameda
# district_code                                                  61275
# district_name                                                    NaN
# district_type                                                    NaN
# school_code                                                   130286
# school_name                              Millennium High Alternative
# school_type                                                      NaN
# lea_name                                       Piedmont City Unified
# charter_funding_type                                             NaN
# charter_school_number                                            NaN
# charter_school_y_n                                               NaN
# direct_funded_charter_school_number                              NaN
# low_grade                                                         09
# high_grade                                                        12
# educational_option_type                                          NaN
# irc                                                              NaN
# fund_type                                                        NaN
# nslp_provision_2_or_3_school                                     NaN
# nslp_provision_status                                            NaN
# provision_2_or_3_school_y_n                                      NaN
# calpads_enrollment                                               NaN
# calpads_enrollment_k_12                                          NaN
# enrollment                                                         0
# enrollment_k_12                                                  NaN
# calpads_fall_1_certification_status                              NaN
# free_meal_count                                                    0
# free_meal_count_k_12                                             NaN
# frpm_count                                                       NaN
# frpm_count_k_12                                                  NaN
# frpm_total_unduplicated_count                                    NaN
# frpm_total_unduplicated_count_k_12                               NaN
# percent_eligible_free                                            NaN
# percent_eligible_free_k_12                                       NaN
# percent_eligible_frpm                                            NaN
# percent_eligible_frpm_k_12                                       NaN
# percent_frpm                                                       7
# reduced_price_meals                                                0
# total_frpm                                                         0
# unadjusted_free_meal_count                                       NaN
# unadjusted_free_meal_count_k_12                                  NaN
# unadjusted_frpm_count                                            NaN
# unadjusted_frpm_count_k_12                                       NaN
# data_source_for_frpm                                             NaN
# data_source_for_provision_2_or_3_school                          NaN
